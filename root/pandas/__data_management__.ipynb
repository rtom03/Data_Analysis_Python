# %%
import pandas as pd


df = pd.read_csv('jobs_data.csv')
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df_modify = df.copy()

df_fill = df_modify['salary_hour_avg'].median()
df_filled = df_modify['salary_hour_avg'].fillna(df_fill)
df_modify['salary_hour_avg'] =df_filled

df
# Out:
#               job_title_short  \
# 0        Senior Data Engineer
# 1                Data Analyst
# 2               Data Engineer
# 3               Data Engineer
# 4               Data Engineer
# 5               Data Engineer
# 6        Senior Data Engineer
# 7               Data Engineer
# 8            Business Analyst
# 9              Data Scientist
# 10              Data Engineer
# 11              Data Engineer
# 12               Data Analyst
# 13       Senior Data Engineer
# 14              Data Engineer
# 15              Data Engineer
# 16              Data Engineer
# 17             Data Scientist
# 18               Data Analyst
# 19             Data Scientist
# 20             Data Scientist
# 21             Data Scientist
# 22              Data Engineer
# 23  Machine Learning Engineer
# 24             Data Scientist
# 25        Senior Data Analyst
# 26              Data Engineer
# 27              Data Engineer
# 28             Data Scientist
# 29             Data Scientist
# ...
